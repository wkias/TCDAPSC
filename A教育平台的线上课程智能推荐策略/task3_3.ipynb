# %%
import pandas as pd
import seaborn as sb
from sklearn.linear_model import LinearRegression

# %%
login = pd.read_csv('results/task1_1_1.csv')
study = pd.read_csv('results/task1_1_2.csv')
users = pd.read_csv('results/task1_1_3.csv')

# %%
study.learn_process = study.learn_process.apply(lambda x:x[7:-2]).astype('int')
study.learn_process = study.learn_process.apply(lambda x:x/100)
study['isfree'] = study.price.apply(lambda x:0 if x else 1)

# %%
X = study.iloc[:,4:]
y = study.learn_process
reg = LinearRegression().fit(X, y)
print(reg.score(X, y))
print(reg.coef_)
# Out:
# 0.001840747287290001
# [-3.42671945e-05 -2.36772601e-02]

# %%
sb.scatterplot(x=study.price, y=study.learn_process).get_figure().savefig('results/task3_3_1.svg')

# %%
sb.heatmap(study.iloc[:,3:-1].corr()).get_figure().savefig('results/task3_3_2.svg')

# %%
study.iloc[:,3:]
# Out:
#         learn_process  price  isfree
# 0                0.00    0.0       1
# 1                0.01    0.0       1
# 2                0.63    0.0       1
# 3                0.00  319.0       0
# 4                0.00  299.0       0
# ...               ...    ...     ...
# 194969           0.00    0.0       1
# 194970           0.04    0.0       1
# 194971           1.00  499.0       0
# 194972           0.00  499.0       0
# 194973           0.04    0.0       1
#
# [194974 rows x 3 columns]

# %%
print(study[study.isfree==1].learn_process.mean())
print(study[study.isfree==0].learn_process.mean())
# Out:
# 0.13772084008177787
# 0.15091986493714896
